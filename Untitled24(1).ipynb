# %%
import requests
import csv
import json
import time

# 🔧 CONFIGURATION
API_KEY = "cqt_rQ9PHYdJqwYdb63kCrGc9xPfwxck"
CHAIN_ID = 1  # Ethereum Mainnet
INPUT_FILE = r'C:\Users\HP\OneDrive\Desktop\wallets.csv'
OUTPUT_FILE = 'covalent_wallet_data1.json'

def load_wallets(file_path):
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        wallets = [row[0].strip().lower() for row in reader if row]
    return wallets

def fetch_wallet_transactions(wallet):
    url = f"https://api.covalenthq.com/v1/{CHAIN_ID}/address/{wallet}/transactions_v2/"
    params = {'key': API_KEY}
    try:
        response = requests.get(url, params=params)
        data = response.json()
        if 'data' in data and data['data']:
            print(f"✅ Data fetched for {wallet}")
            return {'wallet': wallet, 'data': data['data']}
        else:
            print(f"⚠️ No data found for {wallet}")
            return {'wallet': wallet, 'data': None}
    except requests.exceptions.RequestException as e:
        print(f"❌ Request failed for {wallet}: {str(e)}")
        return {'wallet': wallet, 'error': str(e)}

def main():
    wallets = load_wallets(INPUT_FILE)
    all_data = []

    for idx, wallet in enumerate(wallets):
        print(f"\nFetching {idx + 1}/{len(wallets)}: {wallet}")
        result = fetch_wallet_transactions(wallet)
        all_data.append(result)
        time.sleep(1.2)  # Avoid rate limit

    with open(OUTPUT_FILE, 'w') as outfile:
        json.dump(all_data, outfile, indent=2)

    print(f"\n✅ Done. Data saved to {OUTPUT_FILE}")

if __name__ == '__main__':
    main()
# Out:
# Fetching 1/104: ï»¿wallet_id
# ⚠️ No data found for ï»¿wallet_id
#
# Fetching 2/104: 0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# ✅ Data fetched for 0x0039f22efb07a647557c7c5d17854cfd6d489ef3
#
# Fetching 3/104: 0x06b51c6882b27cb05e712185531c1f74996dd988
# ✅ Data fetched for 0x06b51c6882b27cb05e712185531c1f74996dd988
#
# Fetching 4/104: 0x0795732aacc448030ef374374eaae57d2965c16c
# ✅ Data fetched for 0x0795732aacc448030ef374374eaae57d2965c16c
#
# Fetching 5/104: 0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# ✅ Data fetched for 0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
#
# Fetching 6/104: 0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae
# ✅ Data fetched for 0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae
#
# Fetching 7/104: 0x104ae61d8d487ad689969a17807ddc338b445416
# ✅ Data fetched for 0x104ae61d8d487ad689969a17807ddc338b445416
#
# Fetching 8/104: 0x111c7208a7e2af345d36b6d4aace8740d61a3078
# ✅ Data fetched for 0x111c7208a7e2af345d36b6d4aace8740d61a3078
#
# Fetching 9/104: 0x124853fecb522c57d9bd5c21231058696ca6d596
# ✅ Data fetched for 0x124853fecb522c57d9bd5c21231058696ca6d596
#
# Fetching 10/104: 0x13b1c8b0e696aff8b4fee742119b549b605f3cbc
# ✅ Data fetched for 0x13b1c8b0e696aff8b4fee742119b549b605f3cbc
#
# Fetching 11/104: 0x1656f1886c5ab634ac19568cd571bc72f385fdf7
# ✅ Data fetched for 0x1656f1886c5ab634ac19568cd571bc72f385fdf7
#
# Fetching 12/104: 0x1724e16cb8d0e2aa4d08035bc6b5c56b680a3b22
# ✅ Data fetched for 0x1724e16cb8d0e2aa4d08035bc6b5c56b680a3b22
#
# Fetching 13/104: 0x19df3e87f73c4aaf4809295561465b993e102668
# ✅ Data fetched for 0x19df3e87f73c4aaf4809295561465b993e102668
#
# Fetching 14/104: 0x1ab2ccad4fc97c9968ea87d4435326715be32872
# ✅ Data fetched for 0x1ab2ccad4fc97c9968ea87d4435326715be32872
#
# Fetching 15/104: 0x1c1b30ca93ef57452d53885d97a74f61daf2bf4f
# ✅ Data fetched for 0x1c1b30ca93ef57452d53885d97a74f61daf2bf4f
#
# Fetching 16/104: 0x1e43dacdcf863676a6bec8f7d6896d6252fac669
# ✅ Data fetched for 0x1e43dacdcf863676a6bec8f7d6896d6252fac669
#
# Fetching 17/104: 0x22d7510588d90ed5a87e0f838391aaafa707c34b
# ✅ Data fetched for 0x22d7510588d90ed5a87e0f838391aaafa707c34b
#
# Fetching 18/104: 0x24b3460622d835c56d9a4fe352966b9bdc6c20af
# ✅ Data fetched for 0x24b3460622d835c56d9a4fe352966b9bdc6c20af
#
# Fetching 19/104: 0x26750f1f4277221bdb5f6991473c6ece8c821f9d
# ✅ Data fetched for 0x26750f1f4277221bdb5f6991473c6ece8c821f9d
#
# Fetching 20/104: 0x27f72a000d8e9f324583f3a3491ea66998275b28
# ✅ Data fetched for 0x27f72a000d8e9f324583f3a3491ea66998275b28
#
# Fetching 21/104: 0x2844658bf341db96aa247259824f42025e3bcec2
# ✅ Data fetched for 0x2844658bf341db96aa247259824f42025e3bcec2
#
# Fetching 22/104: 0x2a2fde3e1beb508fcf7c137a1d5965f13a17825e
# ✅ Data fetched for 0x2a2fde3e1beb508fcf7c137a1d5965f13a17825e
#
# Fetching 23/104: 0x330513970efd9e8dd606275fb4c50378989b3204
# ✅ Data fetched for 0x330513970efd9e8dd606275fb4c50378989b3204
#
# Fetching 24/104: 0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97
# ✅ Data fetched for 0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97
#
# Fetching 25/104: 0x3867d222ba91236ad4d12c31056626f9e798629c
# ✅ Data fetched for 0x3867d222ba91236ad4d12c31056626f9e798629c
#
# Fetching 26/104: 0x3a44be4581137019f83021eeee72b7dc57756069
# ✅ Data fetched for 0x3a44be4581137019f83021eeee72b7dc57756069
#
# Fetching 27/104: 0x3e69ad05716bdc834db72c4d6d44439a7c8a902b
# ✅ Data fetched for 0x3e69ad05716bdc834db72c4d6d44439a7c8a902b
#
# Fetching 28/104: 0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65
# ✅ Data fetched for 0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65
#
# Fetching 29/104: 0x4814be124d7fe3b240eb46061f7ddfab468fe122
# ✅ Data fetched for 0x4814be124d7fe3b240eb46061f7ddfab468fe122
#
# Fetching 30/104: 0x4839e666e2baf12a51bf004392b35972eeddeabf
# ✅ Data fetched for 0x4839e666e2baf12a51bf004392b35972eeddeabf
#
# Fetching 31/104: 0x4c4d05fe859279c91b074429b5fc451182cec745
# ✅ Data fetched for 0x4c4d05fe859279c91b074429b5fc451182cec745
#
# Fetching 32/104: 0x4d997c89bc659a3e8452038a8101161e7e7e53a7
# ✅ Data fetched for 0x4d997c89bc659a3e8452038a8101161e7e7e53a7
#
# Fetching 33/104: 0x4db0a72edb5ea6c55df929f76e7d5bb14e389860
# ✅ Data fetched for 0x4db0a72edb5ea6c55df929f76e7d5bb14e389860
#
# Fetching 34/104: 0x4e61251336c32e4fe6bfd5fab014846599321389
# ✅ Data fetched for 0x4e61251336c32e4fe6bfd5fab014846599321389
#
# Fetching 35/104: 0x4e6e724f4163b24ffc7ffe662b5f6815b18b4210
# ✅ Data fetched for 0x4e6e724f4163b24ffc7ffe662b5f6815b18b4210
#
# Fetching 36/104: 0x507b6c0d950702f066a9a1bd5e85206f87b065ba
# ✅ Data fetched for 0x507b6c0d950702f066a9a1bd5e85206f87b065ba
#
# Fetching 37/104: 0x54e19653be9d4143b08994906be0e27555e8834d
# ✅ Data fetched for 0x54e19653be9d4143b08994906be0e27555e8834d
#
# Fetching 38/104: 0x56ba823641bfc317afc8459bf27feed6eb9ff59f
# ✅ Data fetched for 0x56ba823641bfc317afc8459bf27feed6eb9ff59f
#
# Fetching 39/104: 0x56cc2bffcb3f86a30c492f9d1a671a1f744d1d2f
# ✅ Data fetched for 0x56cc2bffcb3f86a30c492f9d1a671a1f744d1d2f
#
# Fetching 40/104: 0x578cea5f899b0dfbf05c7fbcfda1a644b2a47787
# ✅ Data fetched for 0x578cea5f899b0dfbf05c7fbcfda1a644b2a47787
#
# Fetching 41/104: 0x58c2a9099a03750e9842d3e9a7780cdd6aa70b86
# ✅ Data fetched for 0x58c2a9099a03750e9842d3e9a7780cdd6aa70b86
#
# Fetching 42/104: 0x58d68d4bcf9725e40353379cec92b90332561683
# ✅ Data fetched for 0x58d68d4bcf9725e40353379cec92b90332561683
#
# Fetching 43/104: 0x5e324b4a564512ea7c93088dba2f8c1bf046a3eb
# ✅ Data fetched for 0x5e324b4a564512ea7c93088dba2f8c1bf046a3eb
#
# Fetching 44/104: 0x612a3500559be7be7703de6dc397afb541a16f7f
# ✅ Data fetched for 0x612a3500559be7be7703de6dc397afb541a16f7f
#
# Fetching 45/104: 0x623af911f493747c216ad389c7805a37019c662d
# ✅ Data fetched for 0x623af911f493747c216ad389c7805a37019c662d
#
# Fetching 46/104: 0x6a2752a534faacaaa153bffbb973dd84e0e5497b
# ✅ Data fetched for 0x6a2752a534faacaaa153bffbb973dd84e0e5497b
#
# Fetching 47/104: 0x6d69ca3711e504658977367e13c300ab198379f1
# ✅ Data fetched for 0x6d69ca3711e504658977367e13c300ab198379f1
#
# Fetching 48/104: 0x6e355417f7f56e7927d1cd971f0b5a1e6d538487
# ✅ Data fetched for 0x6e355417f7f56e7927d1cd971f0b5a1e6d538487
#
# Fetching 49/104: 0x70c1864282599a762c674dd9d567b37e13bce755
# ✅ Data fetched for 0x70c1864282599a762c674dd9d567b37e13bce755
#
# Fetching 50/104: 0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e
# ✅ Data fetched for 0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e
#
# Fetching 51/104: 0x7399dbeebe2f88bc6ac4e3fd7ddb836a4bce322f
# ✅ Data fetched for 0x7399dbeebe2f88bc6ac4e3fd7ddb836a4bce322f
#
# Fetching 52/104: 0x767055590c73b7d2aaa6219da13807c493f91a20
# ✅ Data fetched for 0x767055590c73b7d2aaa6219da13807c493f91a20
#
# Fetching 53/104: 0x7851bdfb64bbecfb40c030d722a1f147dff5db6a
# ✅ Data fetched for 0x7851bdfb64bbecfb40c030d722a1f147dff5db6a
#
# Fetching 54/104: 0x7b4636320daa0bc055368a4f9b9d01bd8ac51877
# ✅ Data fetched for 0x7b4636320daa0bc055368a4f9b9d01bd8ac51877
#
# Fetching 55/104: 0x7b57dbe2f2e4912a29754ff3e412ed9507fd8957
# ✅ Data fetched for 0x7b57dbe2f2e4912a29754ff3e412ed9507fd8957
#
# Fetching 56/104: 0x7be3dfb5b6fcbae542ea85e76cc19916a20f6c1e
# ✅ Data fetched for 0x7be3dfb5b6fcbae542ea85e76cc19916a20f6c1e
#
# Fetching 57/104: 0x7de76a449cf60ea3e111ff18b28e516d89532152
# ✅ Data fetched for 0x7de76a449cf60ea3e111ff18b28e516d89532152
#
# Fetching 58/104: 0x7e3eab408b9c76a13305ef34606f17c16f7b33cc
# ✅ Data fetched for 0x7e3eab408b9c76a13305ef34606f17c16f7b33cc
#
# Fetching 59/104: 0x7f5e6a28afc9fb0aaf4259d4ff69991b88ebea47
# ✅ Data fetched for 0x7f5e6a28afc9fb0aaf4259d4ff69991b88ebea47
#
# Fetching 60/104: 0x83ea74c67d393c6894c34c464657bda2183a2f1a
# ✅ Data fetched for 0x83ea74c67d393c6894c34c464657bda2183a2f1a
#
# Fetching 61/104: 0x8441fecef5cc6f697be2c4fc4a36feacede8df67
# ✅ Data fetched for 0x8441fecef5cc6f697be2c4fc4a36feacede8df67
#
# Fetching 62/104: 0x854a873b8f9bfac36a5eb9c648e285a095a7478d
# ✅ Data fetched for 0x854a873b8f9bfac36a5eb9c648e285a095a7478d
#
# Fetching 63/104: 0x8587d9f794f06d976c2ec1cfd523983b856f5ca9
# ✅ Data fetched for 0x8587d9f794f06d976c2ec1cfd523983b856f5ca9
#
# Fetching 64/104: 0x880a0af12da55df1197f41697c1a1b61670ed410
# ✅ Data fetched for 0x880a0af12da55df1197f41697c1a1b61670ed410
#
# Fetching 65/104: 0x8aaece100580b749a20f8ce30338c4e0770b65ed
# ✅ Data fetched for 0x8aaece100580b749a20f8ce30338c4e0770b65ed
#
# Fetching 66/104: 0x8be38ea2b22b706aef313c2de81f7d179024dd30
# ✅ Data fetched for 0x8be38ea2b22b706aef313c2de81f7d179024dd30
#
# Fetching 67/104: 0x8d900f213db5205c529aaba5d10e71a0ed2646db
# ✅ Data fetched for 0x8d900f213db5205c529aaba5d10e71a0ed2646db
#
# Fetching 68/104: 0x91919344c1dad09772d19ad8ad4f1bcd29c51f27
# ✅ Data fetched for 0x91919344c1dad09772d19ad8ad4f1bcd29c51f27
#
# Fetching 69/104: 0x93f0891bf71d8abed78e0de0885bd26355bb8b1d
# ✅ Data fetched for 0x93f0891bf71d8abed78e0de0885bd26355bb8b1d
#
# Fetching 70/104: 0x96479b087cb8f236a5e2dcbfc50ce63b2f421da6
# ✅ Data fetched for 0x96479b087cb8f236a5e2dcbfc50ce63b2f421da6
#
# Fetching 71/104: 0x96bb4447a02b95f1d1e85374cffd565eb22ed2f8
# ✅ Data fetched for 0x96bb4447a02b95f1d1e85374cffd565eb22ed2f8
#
# Fetching 72/104: 0x9a363adc5d382c04d36b09158286328f75672098
# ✅ Data fetched for 0x9a363adc5d382c04d36b09158286328f75672098
#
# Fetching 73/104: 0x9ad1331c5b6c5a641acffb32719c66a80c6e1a17
# ✅ Data fetched for 0x9ad1331c5b6c5a641acffb32719c66a80c6e1a17
#
# Fetching 74/104: 0x9ba0d85f71e145ccf15225e59631e5a883d5d74a
# ✅ Data fetched for 0x9ba0d85f71e145ccf15225e59631e5a883d5d74a
#
# Fetching 75/104: 0x9e6ec4e98793970a1307262ba68d37594e58cd78
# ✅ Data fetched for 0x9e6ec4e98793970a1307262ba68d37594e58cd78
#
# Fetching 76/104: 0xa7e94d933eb0c439dda357f61244a485246e97b8
# ✅ Data fetched for 0xa7e94d933eb0c439dda357f61244a485246e97b8
#
# Fetching 77/104: 0xa7f3c74f0255796fd5d3ddcf88db769f7a6bf46a
# ✅ Data fetched for 0xa7f3c74f0255796fd5d3ddcf88db769f7a6bf46a
#
# Fetching 78/104: 0xa98dc64bb42575efec7d1e4560c029231ce5da51
# ✅ Data fetched for 0xa98dc64bb42575efec7d1e4560c029231ce5da51
#
# Fetching 79/104: 0xb271ff7090b39028eb6e711c3f89a3453d5861ee
# ✅ Data fetched for 0xb271ff7090b39028eb6e711c3f89a3453d5861ee
#
# Fetching 80/104: 0xb475576594ae44e1f75f534f993cbb7673e4c8b6
# ✅ Data fetched for 0xb475576594ae44e1f75f534f993cbb7673e4c8b6
#
# Fetching 81/104: 0xb57297c5d02def954794e593db93d0a302e43e5c
# ✅ Data fetched for 0xb57297c5d02def954794e593db93d0a302e43e5c
#
# Fetching 82/104: 0xbd4a00764217c13a246f86db58d74541a0c3972a
# ✅ Data fetched for 0xbd4a00764217c13a246f86db58d74541a0c3972a
#
# Fetching 83/104: 0xc179d55f7e00e789915760f7d260a1bf6285278b
# ✅ Data fetched for 0xc179d55f7e00e789915760f7d260a1bf6285278b
#
# Fetching 84/104: 0xc22b8e78394ce52e0034609a67ae3c959daa84bc
# ✅ Data fetched for 0xc22b8e78394ce52e0034609a67ae3c959daa84bc
#
# Fetching 85/104: 0xcbbd9fe837a14258286bbf2e182cbc4e4518c5a3
# ✅ Data fetched for 0xcbbd9fe837a14258286bbf2e182cbc4e4518c5a3
#
# Fetching 86/104: 0xcecf5163bb057c1aff4963d9b9a7d2f0bf591710
# ✅ Data fetched for 0xcecf5163bb057c1aff4963d9b9a7d2f0bf591710
#
# Fetching 87/104: 0xcf0033bf27804640e5339e06443e208db5870dd2
# ✅ Data fetched for 0xcf0033bf27804640e5339e06443e208db5870dd2
#
# Fetching 88/104: 0xd0df53e296c1e3115fccc3d7cdf4ba495e593b56
# ✅ Data fetched for 0xd0df53e296c1e3115fccc3d7cdf4ba495e593b56
#
# Fetching 89/104: 0xd1a3888fd8f490367c6104e10b4154427c02dd9c
# ✅ Data fetched for 0xd1a3888fd8f490367c6104e10b4154427c02dd9c
#
# Fetching 90/104: 0xd334d18fa6bada9a10f361bae42a019ce88a3c33
# ✅ Data fetched for 0xd334d18fa6bada9a10f361bae42a019ce88a3c33
#
# Fetching 91/104: 0xd9d3930ffa343f5a0eec7606d045d0843d3a02b4
# ✅ Data fetched for 0xd9d3930ffa343f5a0eec7606d045d0843d3a02b4
#
# Fetching 92/104: 0xdde73df7bd4d704a89ad8421402701b3a460c6e9
# ✅ Data fetched for 0xdde73df7bd4d704a89ad8421402701b3a460c6e9
#
# Fetching 93/104: 0xde92d70253604fd8c5998c8ee3ed282a41b33b7f
# ✅ Data fetched for 0xde92d70253604fd8c5998c8ee3ed282a41b33b7f
#
# Fetching 94/104: 0xded1f838ae6aa5fcd0f13481b37ee88e5bdccb3d
# ✅ Data fetched for 0xded1f838ae6aa5fcd0f13481b37ee88e5bdccb3d
#
# Fetching 95/104: 0xebb8629e8a3ec86cf90cb7600264415640834483
# ✅ Data fetched for 0xebb8629e8a3ec86cf90cb7600264415640834483
#
# Fetching 96/104: 0xeded1c8c0a0c532195b8432153f3bfa81dba2a90
# ✅ Data fetched for 0xeded1c8c0a0c532195b8432153f3bfa81dba2a90
#
# Fetching 97/104: 0xf10fd8921019615a856c1e95c7cd3632de34edc4
# ✅ Data fetched for 0xf10fd8921019615a856c1e95c7cd3632de34edc4
#
# Fetching 98/104: 0xf340b9f2098f80b86fbc5ede586c319473aa11f3
# ✅ Data fetched for 0xf340b9f2098f80b86fbc5ede586c319473aa11f3
#
# Fetching 99/104: 0xf54f36bca969800fd7d63a68029561309938c09b
# ✅ Data fetched for 0xf54f36bca969800fd7d63a68029561309938c09b
#
# Fetching 100/104: 0xf60304b534f74977e159b2e159e135475c245526
# ✅ Data fetched for 0xf60304b534f74977e159b2e159e135475c245526
#
# Fetching 101/104: 0xf67e8e5805835465f7eba988259db882ab726800
# ✅ Data fetched for 0xf67e8e5805835465f7eba988259db882ab726800
#
# Fetching 102/104: 0xf7aa5d0752cfcd41b0a5945867d619a80c405e52
# ✅ Data fetched for 0xf7aa5d0752cfcd41b0a5945867d619a80c405e52
#
# Fetching 103/104: 0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# ✅ Data fetched for 0xf80a8b9cfff0febf49914c269fb8aead4a22f847
#
# Fetching 104/104: 0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# ✅ Data fetched for 0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
#
# ✅ Done. Data saved to covalent_wallet_data1.json

# %%
import json
import math
from collections import defaultdict
import networkx as nx
import xgboost as xgb
import numpy as np

# --- Load and clean data ---
with open(r"C:\Users\HP\covalent_wallet_data1.json", "r") as f:
    raw_data = json.load(f)

# Flatten tx list
transactions = []
for wallet in raw_data:
    if wallet.get("data") and wallet["data"].get("items"):
        transactions.extend(wallet["data"]["items"])

# --- Build OutTxn and InTxn ---
out_txn = defaultdict(int)
in_txn = defaultdict(int)

for tx in transactions:
    out_txn[tx["from_address"]] += 1
    in_txn[tx["to_address"]] += 1

max_out = max(out_txn.values(), default=1)
max_in = max(in_txn.values(), default=1)

# --- Step 1: De-anonymous Score ---
def calc_score(u, v):
    out_u = out_txn.get(u, 0)
    in_v = in_txn.get(v, 0)

    if out_u == 0 or in_v == 0:
        return -1.0

    s1 = (2 * math.log(out_u) - math.log(max_out)) / math.log(max_out)
    s2 = (2 * math.log(in_v) - math.log(max_in)) / math.log(max_in)
    return 0.5 * (s1 + s2)

# --- Step 2: Build Graph with De-anonymous Scores ---
G = nx.DiGraph()
score_dict = {}
for tx in transactions:
    u = tx.get("from_address")
    v = tx.get("to_address")

    # Skip if from or to address is None
    if u is None or v is None:
        continue

    score = calc_score(u, v)
    if score == -1:
        continue  # skip unscorable edges

    G.add_edge(u, v, score=score)
    score_dict[(u, v)] = score


# --- Step 3: RiskProp Initialization ---
R = defaultdict(lambda: 0.7)  # Reliability
T = defaultdict(float)        # Trustiness
Conf = defaultdict(float)     # Confidence

# --- Step 4: RiskProp Iteration ---
def update_risk(iterations=10):
    for _ in range(iterations):
        # Update T
        for v in G.nodes:
            incoming = G.in_edges(v, data=True)
            if not incoming:
                continue
            sum_scores = sum(score_dict[(u, v)] * Conf[(u, v)] for u, v, d in incoming)
            T[v] = sum_scores / len(incoming)

        # Update Conf
        for u, v, d in G.edges(data=True):
            s_uv = score_dict[(u, v)]
            T_v = T[v]
            Conf[(u, v)] = (R[u] + (1 - abs(s_uv - T_v))) / 2

        # Update R
        for u in G.nodes:
            outgoing = G.out_edges(u)
            if not outgoing:
                continue
            sum_conf = sum(Conf[(u, v)] for u, v in outgoing)
            R[u] = sum_conf / len(outgoing)

update_risk()

# --- Step 5: Final Risk Score ---
risk_scores = {u: (1 - R[u]) * 10 for u in G.nodes}

# --- Print Top Risky Accounts ---
top_risky = sorted(risk_scores.items(), key=lambda x: x[1], reverse=True)[:10]
print("⚠️ Top High-Risk Wallets:")
for addr, risk in top_risky:
    print(f"{addr}: Risk Score = {risk:.2f}")

# --- Step 6: Optional XGBoost Training (if you have labels) ---
# You can use features like: [R, T, average_score, total_txn, in/out ratio] as input to XGBoost

# Example only (pseudo-code)
"""
X = []
y = []  # 1 for scam, 0 for normal
for addr in known_labeled_addresses:
    features = [
        R[addr],
        T[addr],
        len(list(G.successors(addr))),
        len(list(G.predecessors(addr))),
        score_agg_for_addr
    ]
    X.append(features)
    y.append(label_dict[addr])

model = xgb.XGBClassifier()
model.fit(X, y)
"""

# --- GNN Prep Placeholder (if you want to build a GNN later) ---
# Use torch_geometric or DGL for GNN on G with features from R, T, degrees, etc.
# Out:
# ⚠️ Top High-Risk Wallets:
# 0x8a7b54864080b3aeb3321836c1b891c7485e35ec: Risk Score = 8.25
# 0xc4d2571e7f21538e109ef7fbde95bfd3b6be5ef5: Risk Score = 7.87
# 0x80121123bd2850946a0ddd399ade4449ca95cd0d: Risk Score = 7.71
# 0xce18a5129969984f54b88ca860343c3f32c843df: Risk Score = 7.35
# 0x712089481691cbe78ad40e85300eb01294f58a44: Risk Score = 7.11
# 0xaafd0db2f4874b080b40a467b54f0548cd1d88fc: Risk Score = 7.11
# 0x21a31ee1afc51d94c2efccaa2092ad1028285549: Risk Score = 6.73
# 0x09dd9e830d57eca2e683cb5a6706cecef72609c6: Risk Score = 6.70
# 0x87af0ea309642e90dacfadb0c526cc72eb9c89bf: Risk Score = 6.42
# 0xeb4b407df8cf53861507c8302bb40b3e977f0b77: Risk Score = 6.42
# '\nX = []\ny = []  # 1 for scam, 0 for normal\nfor addr in known_labeled_addresses:\n    features = [\n        R[addr],\n        T[addr],\n        len(list(G.successors(addr))),\n        len(list(G.predecessors(addr))),\n        score_agg_for_addr\n    ]\n    X.append(features)\n    y.append(label_dict[addr])\n\nmodel = xgb.XGBClassifier()\nmodel.fit(X, y)\n'
